# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Making Plots Actually Look Nice
# If one has SciencePlots (https://github.com/garrettj403/SciencePlots) installed has additional options for matplotlib.

# %%
plt.style.use(['science','notebook','grid'])

# %% [markdown]
# # Quick Plotting
# ### Line Plots
# Simple plotting commands to look at data quickly

# %%
x=np.linspace(0,15,30)
y=np.sin(x) +0.1*np.random.randn(len(x))
plt.plot(x,y)

# %%
plt.plot(x,y,'--')

# %%
plt.plot(x,y, 'o--', color='purple', lw=2, ms=10)

# %% [markdown]
# Figure size

# %%
plt.figure(figsize=(8,3))
plt.plot(x,y, 'o--', color='purple', lw=2, ms=7)

# %% [markdown]
# Axis labels

# %%
plt.figure(figsize=(8,3))
plt.plot(x,y, 'o--', color='purple', lw=2, ms=7, label='component 1')
plt.xlabel('Time[s]')
plt.ylabel('voltage[V]')
plt.legend(loc='lower right', fontsize=10)
plt.title('Voltage in 3rd Electrode')
# Out:
# Text(0.5, 1.0, 'Voltage in 3rd Electrode')

# %% [markdown]
# Easy to have multiple lines on same plot

# %%
x2=np.linspace(0,15,30)
y2=np.sin(x)

# %%
plt.figure(figsize=(8,3))
plt.plot(x,y, 'o', color='purple', lw=1, ms=5, label='component 1')
plt.plot(x2,y2,'-', color='green',lw=1, label='component 2')
plt.xlabel('Time[s]')
plt.ylabel('voltage[V]')
plt.legend(loc='lower right', fontsize=10)
plt.title('Voltage in 3rd Electrode')
# Out:
# Text(0.5, 1.0, 'Voltage in 3rd Electrode')

# %% [markdown]
# $x$ and $y$ limit

# %%
plt.figure(figsize=(10,3))
plt.plot(x,y, 'o', color='purple', lw=1, ms=5, label='Data')
plt.plot(x2,y2,'-', color='green',lw=1, label='Theory')
plt.xlabel('Time[s]')
plt.ylabel('voltage[V]')
plt.ylim(top=1.5)
plt.legend(loc='upper right', fontsize=10,ncol=2)
plt.title('Voltage in 3rd Electrode')
# Out:
# Text(0.5, 1.0, 'Voltage in 3rd Electrode')

# %% [markdown]
# # Histogram

# %%
res=np.random.randn(1000)*0.2+.4

# %%
plt.figure(figsize=(8,3))
plt.hist(res,bins=30,density=True)
plt.show()

# %% [markdown]
# Different style of Bins

# %%
res2=np.random.randn(1000)*.2+.4
plt.figure(figsize=(8,3))
plt.hist(res2, bins=30, density=True,histtype='step')
plt.hist(res,bins=30,density=True, histtype='step')
plt.show()

# %% [markdown]
# # A More Advanced API
# For more complicated plots, such as
#
# * Multiple subplots on 1 figure
# * Conveniently adding text to plots
# * Creating animations
#
#
# one needs to use a slightly more advanced API
#
# ### Single Axes in one Figure

# %%
fig, ax =plt.subplots(1,1,figsize=(12,4))
ax.plot(x,y,'o--')
ax.set_xlabel('Asd')
ax.set_ylabel('sakdhb')
plt.show()

# %% [markdown]
# Multi Axes in 1 figure

# %%
fig, axes =plt.subplots(3,2,figsize=(12,12))

ax=axes[0][0]
ax.plot(x,y,'o--')
ax.set_xlabel('Asd')
ax.set_ylabel('sakdhb')
ax.text(0.1,0.1,'text here',transform=ax.transAxes)
ax.tick_params(axis='both', labelsize=10)

ax=axes[1][0]
ax.plot(x2,y2,'o--', color='green')
ax.set_xlabel('Asd')
ax.set_ylabel('sakdhb')

ax=axes[2][0]
ax.plot(x,y,'o--')
ax.plot(x2,y2,'o--')
ax.set_xlabel('Asd')
ax.set_ylabel('sakdhb')

ax=axes[0][1]
ax.hist(res,bins=30,density=True)
ax.set_xlabel('Asd')
ax.set_ylabel('sakdhb')
ax.set_title('Histogram')

ax=axes[1][1]
ax.hist(res2, bins=30,density=True, color='green')
ax.set_xlabel('Asd')
ax.set_ylabel('sakdhb')

ax=axes[2][1]
ax.hist(res, bins=30,density=True,histtype='step')
ax.hist(res2, bins=30,density=True, histtype='step')
ax.set_xlabel('Asd')
ax.set_ylabel('sakdhb')
plt.show()

# %% [markdown]
# Can make x-ticks smaller

# %%
plt.style.use(['science', 'notebook', 'grid'])
fig, ax = plt.subplots(1, 1, figsize=(8,3))
ax.plot(x, y, 'o--', color='r', lw=1, ms=5)
ax.text(0.1, 0.1, 'text here', transform=ax.transAxes)
ax.set_xlabel('Time [s]')
ax.set_ylabel(r'$\frac{d}{dx} f(x)$', fontsize=15)
ax.tick_params(axis='both', which='major', labelsize=10)
ax.grid('minor')
plt.show()

# %% [markdown]
# ## Example
#
# Creating the following plot

# %%
res_a1 = 0.2*np.random.randn(1000)+0.4
res_b1 = 0.25*np.random.randn(1000)+0.4
res_a2 = 0.21*np.random.randn(1000)+0.3
res_b2 = 0.22*np.random.randn(1000)+0.3

# %% [markdown]
# Good habit to come up with complicated strings beforehand

# %%
textstr1 = '\n'.join((
    r'$\sigma_a=%.4f$' % (np.std(res_a1)),
    r'$\sigma_b=%.4f$' % (np.std(res_b1))))

textstr2 = '\n'.join((
    r'$\sigma_a=%.4f$' % (np.std(res_a2)),
    r'$\sigma_b=%.4f$' % (np.std(res_b2))))

# %% [markdown]
# Make plot

# %%
fig, axes =plt.subplots(1,2,figsize=(10,3.5))

ax=axes[0]
ax.hist(res_a1,bins=30, density=True,histtype='step', label='a', color='blue')
ax.hist(res_b1,bins=30, density=True,histtype='step', label='b', color='red')
ax.text(0.05,0.81,textstr1,transform=ax.transAxes, bbox=dict(facecolor='white',edgecolor='black'))
ax.set_ylabel('Density')
ax.set_title('Trial 1' )

ax=axes[1]
ax.hist(res_a2,bins=30, density=True,histtype='step', label='a', color='blue')
ax.hist(res_b2,bins=30, density=True,histtype='step', label='b', color='red')
ax.legend(loc='upper right', fancybox=False, edgecolor='black')
ax.text(0.05,0.81,textstr2,transform=ax.transAxes, bbox=dict(facecolor='white',edgecolor='black'))
fig.text(0.5,-0.04,'$\Delta E$[Joules]', ha='center', fontsize=20)
ax.set_title('Trial 2')
plt.show()

# %% [markdown]
# # 2D Plots
#
# Generate some data

# %%
_ = np.linspace(-1, 1, 100)
x, y = np.meshgrid(_,_)
z = x**2+x*y

# %% [markdown]
# ### Filled-in contour plots

# %%
plt.contourf(x,y,z,levels=30,vmin=0,vmax=1.68)
plt.colorbar(label='Voltage')

# %% [markdown]
# Can make them more dense ny changing levels and also can change colormap
#
# See https://matplotlib.org/stable/tutorials/colors/colormaps.html#sphx-glr-tutorials-colors-colormaps-py
# Can use vmin and vmax to adjust the color range
#
# See https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.contour.html for all settings

# %%
plt.contourf(x,y,z,levels=30,vmin=0,vmax=1.68, cmap='plasma')
plt.colorbar(label='Voltage')
plt.show()

# %% [markdown]
# ### Contour plot
# Sometimes, the following is preferred:

# %%
cs=plt.contour(x,y,z,levels=20)
plt.clabel(cs, fontsize=8)
plt.show()

# %% [markdown]
# # 3D Surface plot
#
# 3D Surface Plot (Generally not preferred). However, they tend to work well in animations (we'll get to this later)

# %%
fig, ax =plt.subplots(subplot_kw={'projection':'3d'})
ax.plot_surface(x,y,z, cmap='coolwarm')

# %% [markdown]
# ### StreamPlots

# %%
w = 3
_ = np.linspace(-3,3,100)
X, Y = np.meshgrid(_,_)
U = -1 - X**2 + Y
V = 1 + X - Y**2
speed = np.sqrt(U**2 + V**2)

# %%
fig, axes =plt.subplots(2,2, figsize=(7,7))

ax=axes[0][0]
ax.streamplot(X,Y,U,V)

ax=axes[0][1]
ax.streamplot(X,Y,U,V,color=speed)

ax=axes[1][0]
lw=5*speed/speed.max()
ax.streamplot(X,Y,U,V,linewidth=lw)

ax=axes[1][1]
lw=5*speed/speed.max()
seedpoints=np.array([[0,1],[1,0]])
ax.streamplot(X,Y,U,V,start_points=seedpoints)

# %% [markdown]
# ### Animations
#
# Animations require relating the time of your problem to the frame of the animation, then specifying the frames per second
#
# * Below is a $\sin$ wave moving at 3m/s. Translate this into an animation

# %%
def f(x,t):
    return np.sin(x-3*t)

x = np.linspace(0, 10*np.pi, 1000)

# %% [markdown]
# Create animation

# %%
from matplotlib import animation
from matplotlib.animation import PillowWriter

# %%
fig, ax =plt.subplots(1,1,figsize=(8,4))
ln1=plt.plot([],[])
time_text =ax.text(0.65, 0.95, '', fontsize=15,
                   transform=ax.transAxes, bbox=dict(facecolor='white', edgecolor='black'))

ax.set_xlim(0,10*np.pi)
ax.set_ylim(-1.5,1.5)

def animate(i):
    ln1.set_data(x, f(x, 1/50*i))
    time_text.set_text('t={:.2f}'.format(i/50))
    
ani=animation.FuncAnimation(fig,animate,frames=240,interval=50)
ani.save('.../Python/ani.gif',writer='pillow',fps=50,dpi=100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     250         try:
# --> 251             yield self
#     252         finally:
#
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1143             for anim in all_anim:
# -> 1144                 anim._init_draw()  # Clear the initial frame
#    1145             frame_number = 0
#
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in _init_draw(self)
#    1718         if self._init_func is None:
# -> 1719             self._draw_frame(next(self.new_frame_seq()))
#    1720
#
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in _draw_frame(self, framedata)
#    1741         # func needs to return a sequence of any artists that were modified.
# -> 1742         self._drawn_artists = self._func(framedata, *self._args)
#    1743         if self._blit:
#
# <ipython-input-227-a41d70da50f0> in animate(i)
#       9 def animate(i):
# ---> 10     ln1.set_data(x, f(x, 1/50*i))
#      11     time_text.set_text('t={:.2f}'.format(i/50))
#
# AttributeError: 'list' object has no attribute 'set_data'
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-227-a41d70da50f0> in <module>
#      12
#      13 ani=animation.FuncAnimation(fig,animate,frames=240,interval=50)
# ---> 14 ani.save('.../Python/ani.gif',writer='pillow',fps=50,dpi=100)
#
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1159                         progress_callback(frame_number, total_frames)
#    1160                         frame_number += 1
# -> 1161                 writer.grab_frame(**savefig_kwargs)
#    1162
#    1163     def _step(self, *args):
#
# ~\anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#     129                 value = type()
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#     133                 # Suppress StopIteration *unless* it's the same exception that
#
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     251             yield self
#     252         finally:
# --> 253             self.finish()
#     254
#     255
#
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in finish(self)
#     552
#     553     def finish(self):
# --> 554         self._frames[0].save(
#     555             self.outfile, save_all=True, append_images=self._frames[1:],
#     556             duration=int(1000 / self.fps), loop=0)
#
# IndexError: list index out of range

# %% [markdown]
# The animation function can be used in other ways too. One can create 3D rotating gifs of surfaces.

# %%
_ = np.linspace(-1, 1, 100)
x, y = np.meshgrid(_,_)
z = x**2+x*y

# %%
from matplotlib import animation
from matplotlib.animation import PillowWriter

def f(x,t):
    return np.sin(x-3*t)

x = np.linspace(0, 10*np.pi, 1000)
t = np.arange(0, 24, 1/60)
X, T = np.meshgrid(x, t)
F = f(X, T)

fig, ax = plt.subplots(1,1, figsize=(8,4))
ln1, = plt.plot([], [])
time_text = ax.text(0.65, 0.95, '', fontsize=15,
                    bbox=dict(facecolor='white', edgecolor='black'), 
                    transform=ax.transAxes)
ax.set_xlim(0,10*np.pi)
ax.set_ylim(-1.5, 1.5)

def animate(i):
    ln1.set_data(x, F[i])
    time_text.set_text('t={:.2f}'.format(i/60))
    
ani = animation.FuncAnimation(fig, animate, frames=240, interval=50)
ani.save('C:/Users/HP/OneDrive - Universidad Autonoma de Santo Domingo/Programing/Project/Python/Intro/ani.gif'
         ,writer='pillow',fps=50,dpi=100)

# %%
_ = np.linspace(-1, 1, 100)
x, y = np.meshgrid(_,_)
z = x**2+x*y
plt.style.use('default')

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.plot_surface(x,y,z, cmap='coolwarm',
                       linewidth=0, antialiased=False)
ax.view_init(elev=10, azim=0)

def animate(i):
    ax.view_init(elev=10, azim=3*i)
    
ani = animation.FuncAnimation(fig, animate, frames=120, interval=50)
ani.save('C:/Users/HP/OneDrive - Universidad Autonoma de Santo Domingo/Programing/Project/Python/Intro/ani2.gif',writer='pillow',fps=30,dpi=100)
